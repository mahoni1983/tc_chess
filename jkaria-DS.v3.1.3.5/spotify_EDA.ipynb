# %% [markdown]
# # Data Processing with NumPy and Pandas
# # Top 50 Spotify Tracks- 2020

# %% [markdown]
# https://intra.turingcollege.com/hardskills/data-processing-with-numpy-and-pandas-v3
# https://www.kaggle.com/datasets/atillacolak/top-50-spotify-tracks-2020

# %% [markdown]
# Data Processing with NumPy and Pandas
# Preparation
# Read the instructions below and follow the guidelines.
# Reviews
# About this Part
# Congrats! You've nearly completed the sprint! Great job! In this part, all the skills you've learned will be put to the test. As the final assignment of this Sprint, you'll analyze the Top 50 Spotify Tracks 2020 dataset. To complete this task, you will have to apply everything you've learned so far about Data Analysis, Linear Algebra, NumPy, and Pandas.
#
# P.S. We don't expect perfection - as you progress through the course you will continue to improve and there will be plenty more opportunities to practice and apply your skills in the upcoming sprints. For now just use what you've learned and try your best!
#
# Context
# Imagine you're a data analyst working for Spotify. Your team is responsible for content analysis and in this quarter you've decided to analyze Spotify's top hits to quantify what makes a hit song. Your team's product manager has many ideas and has prepared a list of questions (requirements) that she wants you to answer. After reviewing the list of over 20 questions, you are not in a good mood - it will take a couple of days to get all the answers. Luckily, a few days ago, an experienced data scientist working in your team queried the top 50 tracks for her machine learning project and agreed to share the data with you. This is a great help - your SQL skills are not too sharp yet, and you don't yet know where to find all the relevant tables in your data warehouse. With this dataset, you are confident that you'll be able to answer all of your PM's questions, plus maybe even look into some additional points of interest.
#
# Objectives for this Part
# Practice working with data from Kaggle.
# Practice performing basic EDA.
# Practice reading data, performing queries and filtering data using Pandas.
#
# Evaluation Criteria
# Adherence to the requirements. How well did you meet the requirements?
# Code quality. Was your code well-structured? Did you use the correct levels of abstraction? Did you remove commented-out and unused code? Did you adhere to the PEP8?
# Code performance. Did you use suitable algorithms and data structures to solve the problems?
# Project Review
# During your project review, you should present your project as if talking to a product manager and senior data analyst working in your team. You will have to find the right balance between explaining the business side and the technical aspects of your work. You can assume that both of your colleagues have a strong understanding of and are very interested in the business aspect of your project, so be sure to clearly explain what new insights you've found while analyzing the dataset and which directions look the most promising for further research. However, you should also spend time explaining the technical aspects of your work, especially the more complex or unconventional choices.
#
# During a project review, you may get asked questions that test your understanding of covered topics.
#
# What advantages do NumPy arrays have over Python lists?
# What makes computation on NumPy arrays so fast?
# What are the rules of broadcasting?
# What advantages do Pandas have over NumPy?
# What is a DataFrame in Pandas?

# %% [markdown]
# ### Requirements
# Download the data from Spotify Top 50 Tracks of 2020 dataset.
# Load the data using Pandas.
# Perform data cleaning by:
# Handling missing values.
# Removing duplicate samples and features.
# Treating the outliers.
# Perform exploratory data analysis. Your analysis should provide answers to these questions:
# How many observations are there in this dataset?
# How many features this dataset has?
# Which of the features are categorical?
# Which of the features are numeric?
# Are there any artists that have more than 1 popular track? If yes, which and how many?
# Who was the most popular artist?
# How many artists in total have their songs in the top 50?
# Are there any albums that have more than 1 popular track? If yes, which and how many?
# How many albums in total have their songs in the top 50?
# Which tracks have a danceability score above 0.7?
# Which tracks have a danceability score below 0.4?
# Which tracks have their loudness above -5?
# Which tracks have their loudness below -8?
# Which track is the longest?
# Which track is the shortest?
# Which genre is the most popular?
# Which genres have just one song on the top 50?
# How many genres in total are represented in the top 50?
# Which features are strongly positively correlated?
# Which features are strongly negatively correlated?
# Which features are not correlated?
# How does the danceability score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?
# How does the loudness score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?
# How does the acousticness score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?
# Provide clear explanations in your notebook. Your explanations should inform the reader what you are trying to achieve, the results you got, and what these results mean.
# Provide suggestions for how your analysis could be improved.

# %%
import pandas as pd

# %%
df = pd.read_csv('spotifytoptracks.csv', index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            50 non-null     object
#  1   album             50 non-null     object
#  2   track_name        50 non-null     object
#  3   track_id          50 non-null     object
#  4   energy            50 non-null     float64
#  5   danceability      50 non-null     float64
#  6   key               50 non-null     int64
#  7   loudness          50 non-null     float64
#  8   acousticness      50 non-null     float64
#  9   speechiness       50 non-null     float64
#  10  instrumentalness  50 non-null     float64
#  11  liveness          50 non-null     float64
#  12  valence           50 non-null     float64
#  13  tempo             50 non-null     float64
#  14  duration_ms       50 non-null     int64
#  15  genre             50 non-null     object
# dtypes: float64(9), int64(2), object(5)
# memory usage: 6.6+ KB

# %%
df.head()
# Out:
#         artist                                  album             track_name  \
# 0   The Weeknd                            After Hours        Blinding Lights
# 1  Tones And I                           Dance Monkey           Dance Monkey
# 2  Roddy Ricch  Please Excuse Me For Being Antisocial                The Box
# 3    SAINt JHN                  Roses (Imanbek Remix)  Roses - Imanbek Remix
# 4     Dua Lipa                       Future Nostalgia        Don't Start Now
#
#                  track_id  energy  danceability  key  loudness  acousticness  \
# 0  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1    -5.934       0.00146
# 1  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6    -6.401       0.68800
# 2  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10    -6.687       0.10400
# 3  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8    -5.457       0.01490
# 4  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11    -4.521       0.01230
#
#    speechiness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.0598          0.000095    0.0897    0.334  171.005       200040
# 1       0.0988          0.000161    0.1700    0.540   98.078       209755
# 2       0.0559          0.000000    0.7900    0.642  116.971       196653
# 3       0.0506          0.004320    0.2850    0.894  121.962       176219
# 4       0.0830          0.000000    0.0951    0.679  123.950       183290
#
#                genre
# 0           R&B/Soul
# 1  Alternative/Indie
# 2        Hip-Hop/Rap
# 3   Dance/Electronic
# 4           Nu-disco

# %%
df['key'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 50 entries, 0 to 49
# Series name: key
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     int64
# dtypes: int64(1)
# memory usage: 800.0 bytes

# %% [markdown]
# Handling missing values.

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [artist, album, track_name, track_id, energy, danceability, key, loudness, acousticness, speechiness, instrumentalness, liveness, valence, tempo, duration_ms, genre]
# Index: []

# %% [markdown]
# No missing data

# %% [markdown]
# ### Removing duplicate samples and features.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [artist, album, track_name, track_id, energy, danceability, key, loudness, acousticness, speechiness, instrumentalness, liveness, valence, tempo, duration_ms, genre]
# Index: []

# %%
df.drop_duplicates()
# Out:
#              artist                                              album  \
# 0        The Weeknd                                        After Hours
# 1       Tones And I                                       Dance Monkey
# 2       Roddy Ricch              Please Excuse Me For Being Antisocial
# 3         SAINt JHN                              Roses (Imanbek Remix)
# 4          Dua Lipa                                   Future Nostalgia
# 5            DaBaby                                   BLAME IT ON BABY
# 6      Harry Styles                                          Fine Line
# 7             Powfu                   death bed (coffee for your head)
# 8     Trevor Daniel                                           Nicotine
# 9     Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 10          KAROL G                                               Tusa
# 11   Arizona Zervas                                            ROXANNE
# 12      Post Malone                               Hollywood's Bleeding
# 13        Lil Mosey                                 Certified Hitmaker
# 14    Justin Bieber                                            Changes
# 15            Drake                               Dark Lane Demo Tapes
# 16    Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 17         Doja Cat                                           Hot Pink
# 18         Maroon 5                                           Memories
# 19           Future                                      High Off Life
# 20        Jawsh 685                   Savage Love (Laxed - Siren Beat)
# 21     Harry Styles                                          Fine Line
# 22            Topic                                        Breaking Me
# 23         24kGoldn                             Mood (feat. iann dior)
# 24    Billie Eilish                                everything i wanted
# 25     Shawn Mendes                              Shawn Mendes (Deluxe)
# 26    Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 27          Cardi B                    WAP (feat. Megan Thee Stallion)
# 28         Surfaces                                 Where the Light Is
# 29           Eminem                            Music To Be Murdered By
# 30    Justin Bieber                                            Changes
# 31         Dua Lipa                                   Future Nostalgia
# 32              BTS                         Dynamite (DayTime Version)
# 33            BENEE                                            Hey u x
# 34        Surf Mesa               ily (i love you baby) (feat. Emilee)
# 35        Lady Gaga                                         Chromatica
# 36     Travis Scott                                HIGHEST IN THE ROOM
# 37      Post Malone                               Hollywood's Bleeding
# 38           Maluma                                       PAPI JUANCHO
# 39           Regard                                            Ride It
# 40     Travis Scott                    Birds In The Trap Sing McKnight
# 41  Black Eyed Peas                                        Translation
# 42       THE SCOTTS                                         THE SCOTTS
# 43        Bad Bunny                                           YHLQMDLG
# 44    Billie Eilish                               lovely (with Khalid)
# 45       Juice WRLD                            Goodbye & Good Riddance
# 46    Ariana Grande                                       Stuck with U
# 47          JP Saxe     If the World Was Ending (feat. Julia Michaels)
# 48         Dua Lipa                                   Future Nostalgia
# 49     Travis Scott                                         ASTROWORLD
#
#                                         track_name                track_id  \
# 0                                  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1                                     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 2                                          The Box  0nbXyq5TXYPCO7pr3N8S4I
# 3                            Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5
# 4                                  Don't Start Now  3PfIrDoz19wz7qK7tYeu62
# 5                     ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 6                                 Watermelon Sugar  6UelLqGlWMcVH1E5c4H7lY
# 7                 death bed (coffee for your head)  7eJMfftS33KTjuF7lTsMCx
# 8                                          Falling  2rRJrJEo19S2J82BDsQ3F7
# 9                                Someone You Loved  7qEHsqek33rTcFNT9PFqLf
# 10                                            Tusa  7k4t7uLgtOxPwTpFmtJNTY
# 11                                         ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 12                                         Circles  21jGcNKet2qwijlDFuPiPb
# 13                                 Blueberry Faygo  22LAwLoDA5b4AaGSkg6bKW
# 14                        Intentions (feat. Quavo)  4umIPjkehX1r7uhmGvXiSV
# 15                                    Toosie Slide  466cKvZn1j45IpxDdYZqdA
# 16                                   Before You Go  2gMXnyrvIjhVBUZwvLZDMP
# 17                                          Say So  3Dv1eDb0MEgF93GpLXlucZ
# 18                                        Memories  2b8fOow8UzyDFAE27YhOZM
# 19                      Life Is Good (feat. Drake)  1K5KBOgreBi5fkEHvg5ap3
# 20                Savage Love (Laxed - Siren Beat)  1xQ6trAsedVPCdbtDAmk0c
# 21                                       Adore You  3jjujdWJ72nww5eGnfs2E7
# 22                                     Breaking Me  3H7ihDc1dqLriiWXwsc2po
# 23                          Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq
# 24                             everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 25                                        Señorita  6v3KW9xbzN5yKLt9YKDYA2
# 26                                         bad guy  2Fxmhks0bxGSBdJ92vM42m
# 27                 WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih
# 28                                     Sunday Best  1Cv1YLb4q0RzL6pybtaMLo
# 29                     Godzilla (feat. Juice WRLD)  7FIWs0pqAYbP91WWM0vlTQ
# 30                                           Yummy  16wAOAZ2OkqoIDN7TpChjR
# 31                                  Break My Heart  017PF4Q3l4DBUiWoXk4OWT
# 32                                        Dynamite  0t1kP63rueHleOhQkYSXFY
# 33                Supalonely (feat. Gus Dapperton)  3GZoWLVbmxcBys6g0DLFLf
# 34            ily (i love you baby) (feat. Emilee)  62aP9fBQKYKxi7PDXwcUAS
# 35                 Rain On Me (with Ariana Grande)  7ju97lgwC2rKQ6wwsf9no9
# 36                             HIGHEST IN THE ROOM  3eekarcy7kvN4yt5ZFzltW
# 37   Sunflower - Spider-Man: Into the Spider-Verse  0RiRZpuVRbi7oqRdSMwhQY
# 38                                           Hawái  1yoMvmasuxZfqHEipJhRbp
# 39                                         Ride It  2tnVG71enUj33Ic2nFN6kZ
# 40                                      goosebumps  6gBFPUFcJLzWGx4lenP6h2
# 41                       RITMO (Bad Boys For Life)  4NCsrTzgVfsDo8nWyP8PPc
# 42                                      THE SCOTTS  39Yp9wwQiSRIDOvrVg7mbk
# 43                                         Safaera  2DEZmgHKAvm41k4J3R2E9Y
# 44                            lovely (with Khalid)  0u2P5u6lvoDfwTYjAADbn4
# 45                                    Lucid Dreams  285pBltuF7vW8TeWk8hdRR
# 46               Stuck with U (with Justin Bieber)  4HBZA5flZLE435QTztThqH
# 47  If the World Was Ending - feat. Julia Michaels  2kJwzbxV2ppxnQoYw4GLBZ
# 48                                        Physical  3AzjcOeAmA57TIOr9zF1ZW
# 49                                      SICKO MODE  2xLMifQCjDGFmkHkpNLD9h
#
#     energy  danceability  key  loudness  acousticness  speechiness  \
# 0    0.730         0.514    1    -5.934       0.00146       0.0598
# 1    0.593         0.825    6    -6.401       0.68800       0.0988
# 2    0.586         0.896   10    -6.687       0.10400       0.0559
# 3    0.721         0.785    8    -5.457       0.01490       0.0506
# 4    0.793         0.793   11    -4.521       0.01230       0.0830
# 5    0.690         0.746   11    -7.956       0.24700       0.1640
# 6    0.816         0.548    0    -4.209       0.12200       0.0465
# 7    0.431         0.726    8    -8.765       0.73100       0.1350
# 8    0.430         0.784   10    -8.756       0.12300       0.0364
# 9    0.405         0.501    1    -5.679       0.75100       0.0319
# 10   0.715         0.803    2    -3.280       0.29500       0.2980
# 11   0.601         0.621    6    -5.616       0.05220       0.1480
# 12   0.762         0.695    0    -3.497       0.19200       0.0395
# 13   0.554         0.774    0    -7.909       0.20700       0.0383
# 14   0.546         0.806    9    -6.637       0.30000       0.0575
# 15   0.490         0.830    1    -8.820       0.28900       0.2090
# 16   0.575         0.459    3    -4.858       0.60400       0.0573
# 17   0.673         0.787   11    -4.577       0.25600       0.1580
# 18   0.320         0.764   11    -7.209       0.83700       0.0546
# 19   0.574         0.795    2    -6.903       0.06700       0.4870
# 20   0.481         0.767    0    -8.520       0.23400       0.0803
# 21   0.771         0.676    8    -3.675       0.02370       0.0483
# 22   0.720         0.789    8    -5.652       0.22300       0.2180
# 23   0.722         0.700    7    -3.558       0.22100       0.0369
# 24   0.225         0.704    6   -14.454       0.90200       0.0994
# 25   0.548         0.759    9    -6.049       0.03920       0.0290
# 26   0.425         0.701    7   -10.965       0.32800       0.3750
# 27   0.454         0.935    1    -7.509       0.01940       0.3750
# 28   0.525         0.878    5    -6.832       0.18300       0.0578
# 29   0.745         0.808   10    -5.260       0.14500       0.3420
# 30   0.506         0.676    9    -6.652       0.34500       0.0958
# 31   0.729         0.730    4    -3.434       0.16700       0.0883
# 32   0.765         0.746    6    -4.410       0.01120       0.0993
# 33   0.631         0.862    7    -4.746       0.29100       0.0515
# 34   0.774         0.674   11    -7.567       0.06860       0.0892
# 35   0.855         0.672    9    -3.764       0.02100       0.0397
# 36   0.427         0.598    7    -8.764       0.05460       0.0317
# 37   0.522         0.755    2    -4.368       0.53300       0.0575
# 38   0.727         0.783    6    -3.454       0.18500       0.3890
# 39   0.751         0.880    7    -4.258       0.17700       0.0874
# 40   0.728         0.841    7    -3.370       0.08470       0.0484
# 41   0.704         0.723   10    -7.088       0.02590       0.0571
# 42   0.537         0.716    0    -7.648       0.23300       0.0514
# 43   0.829         0.607    2    -4.074       0.01030       0.3790
# 44   0.296         0.351    4   -10.109       0.93400       0.0333
# 45   0.566         0.511    6    -7.230       0.34900       0.2000
# 46   0.450         0.597    8    -6.658       0.22300       0.0418
# 47   0.473         0.464    1   -10.086       0.86600       0.1290
# 48   0.844         0.647    0    -3.756       0.01370       0.0457
# 49   0.730         0.834    8    -3.714       0.00513       0.2220
#
#     instrumentalness  liveness  valence    tempo  duration_ms  \
# 0           0.000095    0.0897   0.3340  171.005       200040
# 1           0.000161    0.1700   0.5400   98.078       209755
# 2           0.000000    0.7900   0.6420  116.971       196653
# 3           0.004320    0.2850   0.8940  121.962       176219
# 4           0.000000    0.0951   0.6790  123.950       183290
# 5           0.000000    0.1010   0.4970   89.977       181733
# 6           0.000000    0.3350   0.5570   95.390       174000
# 7           0.000000    0.6960   0.3480  144.026       173333
# 8           0.000000    0.0887   0.2360  127.087       159382
# 9           0.000000    0.1050   0.4460  109.891       182161
# 10          0.000134    0.0574   0.5740  101.085       200960
# 11          0.000000    0.4600   0.4570  116.735       163636
# 12          0.002440    0.0863   0.5530  120.042       215280
# 13          0.000000    0.1320   0.3490   99.034       162547
# 14          0.000000    0.1020   0.8740  147.986       212867
# 15          0.000003    0.1130   0.8450   81.604       247059
# 16          0.000000    0.0885   0.1830  111.881       215107
# 17          0.000004    0.0904   0.7860  110.962       237893
# 18          0.000000    0.0822   0.5750   91.019       189486
# 19          0.000000    0.1500   0.5370  142.053       237918
# 20          0.000000    0.2690   0.7610  150.076       171375
# 21          0.000007    0.1020   0.5690   99.048       207133
# 22          0.000000    0.1290   0.6640  122.031       166794
# 23          0.000000    0.2720   0.7560   90.989       140526
# 24          0.657000    0.1060   0.2430  120.006       245426
# 25          0.000000    0.0828   0.7490  116.967       190800
# 26          0.130000    0.1000   0.5620  135.128       194088
# 27          0.000000    0.0824   0.3570  133.073       187541
# 28          0.000000    0.0714   0.6940  112.022       158571
# 29          0.000000    0.2920   0.8290  165.995       210800
# 30          0.000000    0.1180   0.4970  145.842       208520
# 31          0.000001    0.3490   0.4670  113.013       221820
# 32          0.000000    0.0936   0.7370  114.044       199054
# 33          0.000209    0.1230   0.8410  128.978       223488
# 34          0.001880    0.3930   0.3300  112.050       176547
# 35          0.000000    0.3230   0.6460  123.056       182200
# 36          0.000006    0.2100   0.0605   76.469       175721
# 37          0.000000    0.0685   0.9250   89.960       157560
# 38          0.000025    0.0626   0.5580  180.067       199112
# 39          0.000064    0.1060   0.8840  117.948       157606
# 40          0.000000    0.1490   0.4300  130.049       243837
# 41          0.001090    0.7920   0.6840  105.095       214935
# 42          0.000000    0.1570   0.2800  129.979       165978
# 43          0.000000    0.1070   0.6850   96.172       295177
# 44          0.000000    0.0950   0.1200  115.284       200186
# 45          0.000000    0.3400   0.2180   83.903       239836
# 46          0.000000    0.3820   0.5370  178.765       228482
# 47          0.000000    0.1090   0.6040   75.801       208687
# 48          0.000658    0.1020   0.7460  146.967       193829
# 49          0.000000    0.1240   0.4460  155.008       312820
#
#                                  genre
# 0                             R&B/Soul
# 1                    Alternative/Indie
# 2                          Hip-Hop/Rap
# 3                     Dance/Electronic
# 4                             Nu-disco
# 5                          Hip-Hop/Rap
# 6                                  Pop
# 7                          Hip-Hop/Rap
# 8              R&B/Hip-Hop alternative
# 9                    Alternative/Indie
# 10                                 Pop
# 11                         Hip-Hop/Rap
# 12                       Pop/Soft Rock
# 13                         Hip-Hop/Rap
# 14                                 Pop
# 15                         Hip-Hop/Rap
# 16                   Alternative/Indie
# 17                            R&B/Soul
# 18                                 Pop
# 19                         Hip-Hop/Rap
# 20                         Hip-Hop/Rap
# 21                                 Pop
# 22                    Dance/Electronic
# 23                             Pop rap
# 24                                 Pop
# 25                                 Pop
# 26                         Electro-pop
# 27                        Hip-Hop/Trap
# 28                         Electro-pop
# 29                         Hip-Hop/Rap
# 30                                 Pop
# 31                     Dance-pop/Disco
# 32                           Disco-pop
# 33                   Alternative/Indie
# 34                    Dance/Electronic
# 35                                 Pop
# 36                         Hip-Hop/Rap
# 37                Dreampop/Hip-Hop/R&B
# 38                                 Pop
# 39                    Dance/Electronic
# 40                         Hip-Hop/Rap
# 41                                 Pop
# 42                         Hip-Hop/Rap
# 43  Alternative/reggaeton/experimental
# 44                         Chamber pop
# 45                                 Pop
# 46                                 Pop
# 47                                 Pop
# 48                    Dance/Electronic
# 49                         Hip-Hop/Rap

# %% [markdown]
# No duplicates

# %% [markdown]
# ### Treating the outliers.

# %%
df.describe()
# Out:
#           energy  danceability        key   loudness  acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        speechiness  instrumentalness   liveness    valence       tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# 25%       0.048325          0.000000   0.093950   0.434000   99.557250
# 50%       0.070050          0.000000   0.111000   0.560000  116.969000
# 75%       0.155500          0.000020   0.271250   0.726250  132.317000
# max       0.487000          0.657000   0.792000   0.925000  180.067000
#
#          duration_ms
# count      50.000000
# mean   199955.360000
# std     33996.122488
# min    140526.000000
# 25%    175845.500000
# 50%    197853.500000
# 75%    215064.000000
# max    312820.000000

# %%
num_cols = df.describe().columns

# %%
abs(df[num_cols] - df[num_cols].mean()) > (3 * df[num_cols].std())
# Out:
#     energy  danceability    key  loudness  acousticness  speechiness  \
# 0    False         False  False     False         False        False
# 1    False         False  False     False         False        False
# 2    False         False  False     False         False        False
# 3    False         False  False     False         False        False
# 4    False         False  False     False         False        False
# 5    False         False  False     False         False        False
# 6    False         False  False     False         False        False
# 7    False         False  False     False         False        False
# 8    False         False  False     False         False        False
# 9    False         False  False     False         False        False
# 10   False         False  False     False         False        False
# 11   False         False  False     False         False        False
# 12   False         False  False     False         False        False
# 13   False         False  False     False         False        False
# 14   False         False  False     False         False        False
# 15   False         False  False     False         False        False
# 16   False         False  False     False         False        False
# 17   False         False  False     False         False        False
# 18   False         False  False     False         False        False
# 19   False         False  False     False         False         True
# 20   False         False  False     False         False        False
# 21   False         False  False     False         False        False
# 22   False         False  False     False         False        False
# 23   False         False  False     False         False        False
# 24   False         False  False      True         False        False
# 25   False         False  False     False         False        False
# 26   False         False  False     False         False        False
# 27   False         False  False     False         False        False
# 28   False         False  False     False         False        False
# 29   False         False  False     False         False        False
# 30   False         False  False     False         False        False
# 31   False         False  False     False         False        False
# 32   False         False  False     False         False        False
# 33   False         False  False     False         False        False
# 34   False         False  False     False         False        False
# 35   False         False  False     False         False        False
# 36   False         False  False     False         False        False
# 37   False         False  False     False         False        False
# 38   False         False  False     False         False        False
# 39   False         False  False     False         False        False
# 40   False         False  False     False         False        False
# 41   False         False  False     False         False        False
# 42   False         False  False     False         False        False
# 43   False         False  False     False         False        False
# 44   False         False  False     False         False        False
# 45   False         False  False     False         False        False
# 46   False         False  False     False         False        False
# 47   False         False  False     False         False        False
# 48   False         False  False     False         False        False
# 49   False         False  False     False         False        False
#
#     instrumentalness  liveness  valence  tempo  duration_ms
# 0              False     False    False  False        False
# 1              False     False    False  False        False
# 2              False      True    False  False        False
# 3              False     False    False  False        False
# 4              False     False    False  False        False
# 5              False     False    False  False        False
# 6              False     False    False  False        False
# 7              False     False    False  False        False
# 8              False     False    False  False        False
# 9              False     False    False  False        False
# 10             False     False    False  False        False
# 11             False     False    False  False        False
# 12             False     False    False  False        False
# 13             False     False    False  False        False
# 14             False     False    False  False        False
# 15             False     False    False  False        False
# 16             False     False    False  False        False
# 17             False     False    False  False        False
# 18             False     False    False  False        False
# 19             False     False    False  False        False
# 20             False     False    False  False        False
# 21             False     False    False  False        False
# 22             False     False    False  False        False
# 23             False     False    False  False        False
# 24              True     False    False  False        False
# 25             False     False    False  False        False
# 26             False     False    False  False        False
# 27             False     False    False  False        False
# 28             False     False    False  False        False
# 29             False     False    False  False        False
# 30             False     False    False  False        False
# 31             False     False    False  False        False
# 32             False     False    False  False        False
# 33             False     False    False  False        False
# 34             False     False    False  False        False
# 35             False     False    False  False        False
# 36             False     False    False  False        False
# 37             False     False    False  False        False
# 38             False     False    False  False        False
# 39             False     False    False  False        False
# 40             False     False    False  False        False
# 41             False      True    False  False        False
# 42             False     False    False  False        False
# 43             False     False    False  False        False
# 44             False     False    False  False        False
# 45             False     False    False  False        False
# 46             False     False    False  False        False
# 47             False     False    False  False        False
# 48             False     False    False  False        False
# 49             False     False    False  False         True

# %%
df[(abs(df[num_cols] - df[num_cols].mean()) > (3 * df[num_cols].std())).any(axis=1)]
# Out:
#              artist                                  album  \
# 2       Roddy Ricch  Please Excuse Me For Being Antisocial
# 19           Future                          High Off Life
# 24    Billie Eilish                    everything i wanted
# 41  Black Eyed Peas                            Translation
# 49     Travis Scott                             ASTROWORLD
#
#                     track_name                track_id  energy  danceability  \
# 2                      The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896
# 19  Life Is Good (feat. Drake)  1K5KBOgreBi5fkEHvg5ap3   0.574         0.795
# 24         everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ   0.225         0.704
# 41   RITMO (Bad Boys For Life)  4NCsrTzgVfsDo8nWyP8PPc   0.704         0.723
# 49                  SICKO MODE  2xLMifQCjDGFmkHkpNLD9h   0.730         0.834
#
#     key  loudness  acousticness  speechiness  instrumentalness  liveness  \
# 2    10    -6.687       0.10400       0.0559           0.00000     0.790
# 19    2    -6.903       0.06700       0.4870           0.00000     0.150
# 24    6   -14.454       0.90200       0.0994           0.65700     0.106
# 41   10    -7.088       0.02590       0.0571           0.00109     0.792
# 49    8    -3.714       0.00513       0.2220           0.00000     0.124
#
#     valence    tempo  duration_ms        genre
# 2     0.642  116.971       196653  Hip-Hop/Rap
# 19    0.537  142.053       237918  Hip-Hop/Rap
# 24    0.243  120.006       245426          Pop
# 41    0.684  105.095       214935          Pop
# 49    0.446  155.008       312820  Hip-Hop/Rap

# %% [markdown]
# There are values lying outside of 3 sigmas. All values look adequate, let's count as there are no outliers in the dataset.

# %% [markdown]
# ## Perform exploratory data analysis. Your analysis should provide answers to these questions:

# %% [markdown]
# ### How many observations are there in this dataset?

# %%
df.shape[0]
# Out:
# 50

# %% [markdown]
# ### How many features this dataset has?

# %%
df.shape[1]
# Out:
# 16

# %%
df.columns
# Out:
# Index(['artist', 'album', 'track_name', 'track_id', 'energy', 'danceability',
#        'key', 'loudness', 'acousticness', 'speechiness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'genre'],
#       dtype='object')

# %% [markdown]
# ### Which of the features are categorical?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            50 non-null     object
#  1   album             50 non-null     object
#  2   track_name        50 non-null     object
#  3   track_id          50 non-null     object
#  4   energy            50 non-null     float64
#  5   danceability      50 non-null     float64
#  6   key               50 non-null     int64
#  7   loudness          50 non-null     float64
#  8   acousticness      50 non-null     float64
#  9   speechiness       50 non-null     float64
#  10  instrumentalness  50 non-null     float64
#  11  liveness          50 non-null     float64
#  12  valence           50 non-null     float64
#  13  tempo             50 non-null     float64
#  14  duration_ms       50 non-null     int64
#  15  genre             50 non-null     object
# dtypes: float64(9), int64(2), object(5)
# memory usage: 6.6+ KB

# %%
df['genre'].dtype
# Out:
# dtype('O')

# %%
df['genre'].apply(type)[0]
# Out:
# str

# %%
cols_categorical = [col for col in df.columns if df[col].dtype == "object"]

# %%
cols_categorical
# Out:
# ['artist', 'album', 'track_name', 'track_id', 'genre']

# %% [markdown]
# Categorical feature: 'genre'

# %% [markdown]
# ### Which of the features are numeric?

# %%
set(df.columns) - set(cols_categorical)
# Out:
# {'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'tempo',
#  'valence'}

# %% [markdown]
# Numeric features: 'acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'tempo',
#  'valence'

# %% [markdown]
# ### Are there any artists that have more than 1 popular track? If yes, which and how many?

# %%
df['artist'].value_counts()
# Out:
# artist
# Dua Lipa           3
# Billie Eilish      3
# Travis Scott       3
# Harry Styles       2
# Lewis Capaldi      2
# Justin Bieber      2
# Post Malone        2
# The Weeknd         1
# Powfu              1
# DaBaby             1
# Roddy Ricch        1
# SAINt JHN          1
# Tones And I        1
# Arizona Zervas     1
# Lil Mosey          1
# KAROL G            1
# Drake              1
# Doja Cat           1
# Future             1
# Maroon 5           1
# Jawsh 685          1
# Topic              1
# 24kGoldn           1
# Trevor Daniel      1
# Shawn Mendes       1
# Cardi B            1
# Eminem             1
# Surfaces           1
# BTS                1
# BENEE              1
# Surf Mesa          1
# Lady Gaga          1
# Maluma             1
# Regard             1
# Black Eyed Peas    1
# THE SCOTTS         1
# Bad Bunny          1
# Juice WRLD         1
# Ariana Grande      1
# JP Saxe            1
# Name: count, dtype: int64

# %%
df[df['artist'].map(df['artist'].value_counts()) > 1]
# Out:
#            artist                                              album  \
# 4        Dua Lipa                                   Future Nostalgia
# 6    Harry Styles                                          Fine Line
# 9   Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 12    Post Malone                               Hollywood's Bleeding
# 14  Justin Bieber                                            Changes
# 16  Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 21   Harry Styles                                          Fine Line
# 24  Billie Eilish                                everything i wanted
# 26  Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 30  Justin Bieber                                            Changes
# 31       Dua Lipa                                   Future Nostalgia
# 36   Travis Scott                                HIGHEST IN THE ROOM
# 37    Post Malone                               Hollywood's Bleeding
# 40   Travis Scott                    Birds In The Trap Sing McKnight
# 44  Billie Eilish                               lovely (with Khalid)
# 48       Dua Lipa                                   Future Nostalgia
# 49   Travis Scott                                         ASTROWORLD
#
#                                        track_name                track_id  \
# 4                                 Don't Start Now  3PfIrDoz19wz7qK7tYeu62
# 6                                Watermelon Sugar  6UelLqGlWMcVH1E5c4H7lY
# 9                               Someone You Loved  7qEHsqek33rTcFNT9PFqLf
# 12                                        Circles  21jGcNKet2qwijlDFuPiPb
# 14                       Intentions (feat. Quavo)  4umIPjkehX1r7uhmGvXiSV
# 16                                  Before You Go  2gMXnyrvIjhVBUZwvLZDMP
# 21                                      Adore You  3jjujdWJ72nww5eGnfs2E7
# 24                            everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 26                                        bad guy  2Fxmhks0bxGSBdJ92vM42m
# 30                                          Yummy  16wAOAZ2OkqoIDN7TpChjR
# 31                                 Break My Heart  017PF4Q3l4DBUiWoXk4OWT
# 36                            HIGHEST IN THE ROOM  3eekarcy7kvN4yt5ZFzltW
# 37  Sunflower - Spider-Man: Into the Spider-Verse  0RiRZpuVRbi7oqRdSMwhQY
# 40                                     goosebumps  6gBFPUFcJLzWGx4lenP6h2
# 44                           lovely (with Khalid)  0u2P5u6lvoDfwTYjAADbn4
# 48                                       Physical  3AzjcOeAmA57TIOr9zF1ZW
# 49                                     SICKO MODE  2xLMifQCjDGFmkHkpNLD9h
#
#     energy  danceability  key  loudness  acousticness  speechiness  \
# 4    0.793         0.793   11    -4.521       0.01230       0.0830
# 6    0.816         0.548    0    -4.209       0.12200       0.0465
# 9    0.405         0.501    1    -5.679       0.75100       0.0319
# 12   0.762         0.695    0    -3.497       0.19200       0.0395
# 14   0.546         0.806    9    -6.637       0.30000       0.0575
# 16   0.575         0.459    3    -4.858       0.60400       0.0573
# 21   0.771         0.676    8    -3.675       0.02370       0.0483
# 24   0.225         0.704    6   -14.454       0.90200       0.0994
# 26   0.425         0.701    7   -10.965       0.32800       0.3750
# 30   0.506         0.676    9    -6.652       0.34500       0.0958
# 31   0.729         0.730    4    -3.434       0.16700       0.0883
# 36   0.427         0.598    7    -8.764       0.05460       0.0317
# 37   0.522         0.755    2    -4.368       0.53300       0.0575
# 40   0.728         0.841    7    -3.370       0.08470       0.0484
# 44   0.296         0.351    4   -10.109       0.93400       0.0333
# 48   0.844         0.647    0    -3.756       0.01370       0.0457
# 49   0.730         0.834    8    -3.714       0.00513       0.2220
#
#     instrumentalness  liveness  valence    tempo  duration_ms  \
# 4           0.000000    0.0951   0.6790  123.950       183290
# 6           0.000000    0.3350   0.5570   95.390       174000
# 9           0.000000    0.1050   0.4460  109.891       182161
# 12          0.002440    0.0863   0.5530  120.042       215280
# 14          0.000000    0.1020   0.8740  147.986       212867
# 16          0.000000    0.0885   0.1830  111.881       215107
# 21          0.000007    0.1020   0.5690   99.048       207133
# 24          0.657000    0.1060   0.2430  120.006       245426
# 26          0.130000    0.1000   0.5620  135.128       194088
# 30          0.000000    0.1180   0.4970  145.842       208520
# 31          0.000001    0.3490   0.4670  113.013       221820
# 36          0.000006    0.2100   0.0605   76.469       175721
# 37          0.000000    0.0685   0.9250   89.960       157560
# 40          0.000000    0.1490   0.4300  130.049       243837
# 44          0.000000    0.0950   0.1200  115.284       200186
# 48          0.000658    0.1020   0.7460  146.967       193829
# 49          0.000000    0.1240   0.4460  155.008       312820
#
#                    genre
# 4               Nu-disco
# 6                    Pop
# 9      Alternative/Indie
# 12         Pop/Soft Rock
# 14                   Pop
# 16     Alternative/Indie
# 21                   Pop
# 24                   Pop
# 26           Electro-pop
# 30                   Pop
# 31       Dance-pop/Disco
# 36           Hip-Hop/Rap
# 37  Dreampop/Hip-Hop/R&B
# 40           Hip-Hop/Rap
# 44           Chamber pop
# 48      Dance/Electronic
# 49           Hip-Hop/Rap

# %%
tracks_by_artists = df['artist'].value_counts()

# %%
tracks_by_artists
# Out:
# artist
# Dua Lipa           3
# Billie Eilish      3
# Travis Scott       3
# Harry Styles       2
# Lewis Capaldi      2
# Justin Bieber      2
# Post Malone        2
# The Weeknd         1
# Powfu              1
# DaBaby             1
# Roddy Ricch        1
# SAINt JHN          1
# Tones And I        1
# Arizona Zervas     1
# Lil Mosey          1
# KAROL G            1
# Drake              1
# Doja Cat           1
# Future             1
# Maroon 5           1
# Jawsh 685          1
# Topic              1
# 24kGoldn           1
# Trevor Daniel      1
# Shawn Mendes       1
# Cardi B            1
# Eminem             1
# Surfaces           1
# BTS                1
# BENEE              1
# Surf Mesa          1
# Lady Gaga          1
# Maluma             1
# Regard             1
# Black Eyed Peas    1
# THE SCOTTS         1
# Bad Bunny          1
# Juice WRLD         1
# Ariana Grande      1
# JP Saxe            1
# Name: count, dtype: int64

# %%
tracks_by_artists[tracks_by_artists>1]
# Out:
# artist
# Dua Lipa         3
# Billie Eilish    3
# Travis Scott     3
# Harry Styles     2
# Lewis Capaldi    2
# Justin Bieber    2
# Post Malone      2
# Name: count, dtype: int64

# %%
tracks_by_artists[tracks_by_artists>1].count()
# Out:
# np.int64(7)

# %%
tracks_by_artists[tracks_by_artists>1].index
# Out:
# Index(['Dua Lipa', 'Billie Eilish', 'Travis Scott', 'Harry Styles',
#        'Lewis Capaldi', 'Justin Bieber', 'Post Malone'],
#       dtype='object', name='artist')

# %% [markdown]
# 7 artists with more than one track in the list: ['Dua Lipa', 'Billie Eilish', 'Travis Scott', 'Harry Styles', 'Lewis Capaldi', 'Justin Bieber', 'Post Malone']

# %% [markdown]
# ### Who was the most popular artist?

# %%
tracks_by_artists.max()
# Out:
# np.int64(3)

# %%
tracks_by_artists[tracks_by_artists == tracks_by_artists.max()].index
# Out:
# Index(['Dua Lipa', 'Billie Eilish', 'Travis Scott'], dtype='object', name='artist')

# %% [markdown]
# The most popular artists (with 3 songs in the list): 'Dua Lipa', 'Billie Eilish', 'Travis Scott'

# %% [markdown]
# ### How many artists in total have their songs in the top 50?

# %%
len(df['artist'].unique())
# Out:
# 40

# %% [markdown]
# 40 artists in total have their songs in the top 50

# %% [markdown]
# ### Are there any albums that have more than 1 popular track? If yes, which and how many?

# %%
album_counts = df['album'].value_counts()

# %%
album_counts[album_counts>1]
# Out:
# album
# Future Nostalgia        3
# Hollywood's Bleeding    2
# Fine Line               2
# Changes                 2
# Name: count, dtype: int64

# %% [markdown]
# albums that have more than 1 popular track and tracks number:
# Future Nostalgia        3,
# Hollywood's Bleeding    2,
# Fine Line               2,
# Changes                 2

# %% [markdown]
# ### How many albums in total have their songs in the top 50?

# %%
df['album'].nunique()
# Out:
# 45

# %% [markdown]
# albums in total have their songs in the top 50: 45

# %% [markdown]
# ### Which tracks have a danceability score above 0.7?

# %%
df['track_name'][df['danceability']>0.7]
# Out:
# 1                                      Dance Monkey
# 2                                           The Box
# 3                             Roses - Imanbek Remix
# 4                                   Don't Start Now
# 5                      ROCKSTAR (feat. Roddy Ricch)
# 7                  death bed (coffee for your head)
# 8                                           Falling
# 10                                             Tusa
# 13                                  Blueberry Faygo
# 14                         Intentions (feat. Quavo)
# 15                                     Toosie Slide
# 17                                           Say So
# 18                                         Memories
# 19                       Life Is Good (feat. Drake)
# 20                 Savage Love (Laxed - Siren Beat)
# 22                                      Breaking Me
# 24                              everything i wanted
# 25                                         Señorita
# 26                                          bad guy
# 27                  WAP (feat. Megan Thee Stallion)
# 28                                      Sunday Best
# 29                      Godzilla (feat. Juice WRLD)
# 31                                   Break My Heart
# 32                                         Dynamite
# 33                 Supalonely (feat. Gus Dapperton)
# 37    Sunflower - Spider-Man: Into the Spider-Verse
# 38                                            Hawái
# 39                                          Ride It
# 40                                       goosebumps
# 41                        RITMO (Bad Boys For Life)
# 42                                       THE SCOTTS
# 49                                       SICKO MODE
# Name: track_name, dtype: object

# %%
df['track_name'][df['danceability']>0.7].values
df['track_name'][df['danceability']>0.7].count()
# Out:
# np.int64(32)

# %% [markdown]
# 32 tracks have a danceability score above 0.7: 'Dance Monkey', 'The Box', 'Roses - Imanbek Remix',
#        "Don't Start Now", 'ROCKSTAR (feat. Roddy Ricch)',
#        'death bed (coffee for your head)', 'Falling', 'Tusa',
#        'Blueberry Faygo', 'Intentions (feat. Quavo)', 'Toosie Slide',
#        'Say So', 'Memories', 'Life Is Good (feat. Drake)',
#        'Savage Love (Laxed - Siren Beat)', 'Breaking Me',
#        'everything i wanted', 'Señorita', 'bad guy',
#        'WAP (feat. Megan Thee Stallion)', 'Sunday Best',
#        'Godzilla (feat. Juice WRLD)', 'Break My Heart', 'Dynamite',
#        'Supalonely (feat. Gus Dapperton)',
#        'Sunflower - Spider-Man: Into the Spider-Verse', 'Hawái',
#        'Ride It', 'goosebumps', 'RITMO (Bad Boys For Life)', 'THE SCOTTS',
#        'SICKO MODE'

# %% [markdown]
# ### Which tracks have a danceability score below 0.4?

# %%
df['track_name'][df['danceability']<0.4]
# Out:
# 44    lovely (with Khalid)
# Name: track_name, dtype: object

# %% [markdown]
# only 1 track has a danceability score below 0.4: lovely (with Khalid)

# %% [markdown]
# ### Which tracks have their loudness above -5?

# %%
df['track_name'][df['loudness']>-5]
# Out:
# 4                                   Don't Start Now
# 6                                  Watermelon Sugar
# 10                                             Tusa
# 12                                          Circles
# 16                                    Before You Go
# 17                                           Say So
# 21                                        Adore You
# 23                           Mood (feat. iann dior)
# 31                                   Break My Heart
# 32                                         Dynamite
# 33                 Supalonely (feat. Gus Dapperton)
# 35                  Rain On Me (with Ariana Grande)
# 37    Sunflower - Spider-Man: Into the Spider-Verse
# 38                                            Hawái
# 39                                          Ride It
# 40                                       goosebumps
# 43                                          Safaera
# 48                                         Physical
# 49                                       SICKO MODE
# Name: track_name, dtype: object

# %%
df['track_name'][df['loudness']>-5].values
# Out:
# array(["Don't Start Now", 'Watermelon Sugar', 'Tusa', 'Circles',
#        'Before You Go', 'Say So', 'Adore You', 'Mood (feat. iann dior)',
#        'Break My Heart', 'Dynamite', 'Supalonely (feat. Gus Dapperton)',
#        'Rain On Me (with Ariana Grande)',
#        'Sunflower - Spider-Man: Into the Spider-Verse', 'Hawái',
#        'Ride It', 'goosebumps', 'Safaera', 'Physical', 'SICKO MODE'],
#       dtype=object)

# %%
df['track_name'][df['loudness']>-5].count()
# Out:
# np.int64(19)

# %% [markdown]
# 19 tracks have their loudness above -5: "Don't Start Now", 'Watermelon Sugar', 'Tusa', 'Circles',
#        'Before You Go', 'Say So', 'Adore You', 'Mood (feat. iann dior)',
#        'Break My Heart', 'Dynamite', 'Supalonely (feat. Gus Dapperton)',
#        'Rain On Me (with Ariana Grande)',
#        'Sunflower - Spider-Man: Into the Spider-Verse', 'Hawái',
#        'Ride It', 'goosebumps', 'Safaera', 'Physical', 'SICKO MODE'

# %% [markdown]
# ### Which tracks have their loudness below -8?

# %%
df['track_name'][df['loudness']<-8]
# Out:
# 7                   death bed (coffee for your head)
# 8                                            Falling
# 15                                      Toosie Slide
# 20                  Savage Love (Laxed - Siren Beat)
# 24                               everything i wanted
# 26                                           bad guy
# 36                               HIGHEST IN THE ROOM
# 44                              lovely (with Khalid)
# 47    If the World Was Ending - feat. Julia Michaels
# Name: track_name, dtype: object

# %%
df['track_name'][df['loudness']<-8].values
# Out:
# array(['death bed (coffee for your head)', 'Falling', 'Toosie Slide',
#        'Savage Love (Laxed - Siren Beat)', 'everything i wanted',
#        'bad guy', 'HIGHEST IN THE ROOM', 'lovely (with Khalid)',
#        'If the World Was Ending - feat. Julia Michaels'], dtype=object)

# %% [markdown]
# 9 tracks have their loudness below -8: 'death bed (coffee for your head)', 'Falling', 'Toosie Slide',
#        'Savage Love (Laxed - Siren Beat)', 'everything i wanted',
#        'bad guy', 'HIGHEST IN THE ROOM', 'lovely (with Khalid)',
#        'If the World Was Ending - feat. Julia Michaels'

# %% [markdown]
# ### Which track is the longest?

# %%
df['duration_ms'].idxmax()
# Out:
# np.int64(49)

# %%
df.iloc[df['duration_ms'].idxmax()]
# Out:
# artist                        Travis Scott
# album                           ASTROWORLD
# track_name                      SICKO MODE
# track_id            2xLMifQCjDGFmkHkpNLD9h
# energy                                0.73
# danceability                         0.834
# key                                      8
# loudness                            -3.714
# acousticness                       0.00513
# speechiness                          0.222
# instrumentalness                       0.0
# liveness                             0.124
# valence                              0.446
# tempo                              155.008
# duration_ms                         312820
# genre                          Hip-Hop/Rap
# Name: 49, dtype: object

# %% [markdown]
# 'SICKO MODE' is the longest in the list with 312 secs (5mins 12 secs)

# %% [markdown]
# ### Which track is the shortest?

# %%
df.iloc[df['duration_ms'].idxmin()]
# Out:
# artist                            24kGoldn
# album               Mood (feat. iann dior)
# track_name          Mood (feat. iann dior)
# track_id            3tjFYV6RSFtuktYl3ZtYcq
# energy                               0.722
# danceability                           0.7
# key                                      7
# loudness                            -3.558
# acousticness                         0.221
# speechiness                         0.0369
# instrumentalness                       0.0
# liveness                             0.272
# valence                              0.756
# tempo                               90.989
# duration_ms                         140526
# genre                              Pop rap
# Name: 23, dtype: object

# %% [markdown]
# 'Mood (feat. iann dior)' is the shortest song: 141 secs (2 mins 21 secs)

# %% [markdown]
# ### Which genre is the most popular?

# %%
genre_count = df['genre'].value_counts()

# %%
genre_count
# Out:
# genre
# Pop                                   14
# Hip-Hop/Rap                           13
# Dance/Electronic                       5
# Alternative/Indie                      4
# R&B/Soul                               2
#  Electro-pop                           2
# R&B/Hip-Hop alternative                1
# Nu-disco                               1
# Pop/Soft Rock                          1
# Pop rap                                1
# Hip-Hop/Trap                           1
# Dance-pop/Disco                        1
# Disco-pop                              1
# Dreampop/Hip-Hop/R&B                   1
# Alternative/reggaeton/experimental     1
# Chamber pop                            1
# Name: count, dtype: int64

# %%
genre_count[genre_count == genre_count.iloc[0]]
# Out:
# genre
# Pop    14
# Name: count, dtype: int64

# %% [markdown]
# POP genre has the greatest number songs in the list: 14.

# %% [markdown]
# ### Which genres have just one song on the top 50?

# %%
genre_count[genre_count == 1].index
# Out:
# Index(['R&B/Hip-Hop alternative', 'Nu-disco', 'Pop/Soft Rock', 'Pop rap',
#        'Hip-Hop/Trap', 'Dance-pop/Disco', 'Disco-pop', 'Dreampop/Hip-Hop/R&B',
#        'Alternative/reggaeton/experimental', 'Chamber pop'],
#       dtype='object', name='genre')

# %%
genre_count[genre_count == 1].count()
# Out:
# np.int64(10)

# %% [markdown]
# 10 genres have just one song on the top 50: 'R&B/Hip-Hop alternative', 'Nu-disco', 'Pop/Soft Rock', 'Pop rap', 'Hip-Hop/Trap', 'Dance-pop/Disco', 'Disco-pop', 'Dreampop/Hip-Hop/R&B', 'Alternative/reggaeton/experimental', 'Chamber pop'

# %% [markdown]
# ### How many genres in total are represented in the top 50?

# %%
df['genre'].nunique()
# Out:
# 16

# %% [markdown]
# 16 genres in total are represented in the top 50

# %% [markdown]
# ### Which features are strongly positively correlated?

# %%
cols_numeric = [col for col in df.columns if df[col].dtype != "object"]

# %%
cor_matrix = df[cols_numeric].corr()

# %%
cor_matrix
# Out:
#                     energy  danceability       key  loudness  acousticness  \
# energy            1.000000      0.152552  0.062428  0.791640     -0.682479
# danceability      0.152552      1.000000  0.285036  0.167147     -0.359135
# key               0.062428      0.285036  1.000000 -0.009178     -0.113394
# loudness          0.791640      0.167147 -0.009178  1.000000     -0.498695
# acousticness     -0.682479     -0.359135 -0.113394 -0.498695      1.000000
# speechiness       0.074267      0.226148 -0.094965 -0.021693     -0.135392
# instrumentalness -0.385515     -0.017706  0.020802 -0.553735      0.352184
# liveness          0.069487     -0.006648  0.278672 -0.069939     -0.128384
# valence           0.393453      0.479953  0.120007  0.406772     -0.243192
# tempo             0.075191      0.168956  0.080475  0.102097     -0.241119
# duration_ms       0.081971     -0.033763 -0.003345  0.064130     -0.010988
#
#                   speechiness  instrumentalness  liveness   valence     tempo  \
# energy               0.074267         -0.385515  0.069487  0.393453  0.075191
# danceability         0.226148         -0.017706 -0.006648  0.479953  0.168956
# key                 -0.094965          0.020802  0.278672  0.120007  0.080475
# loudness            -0.021693         -0.553735 -0.069939  0.406772  0.102097
# acousticness        -0.135392          0.352184 -0.128384 -0.243192 -0.241119
# speechiness          1.000000          0.028948 -0.142957  0.053867  0.215504
# instrumentalness     0.028948          1.000000 -0.087034 -0.203283  0.018853
# liveness            -0.142957         -0.087034  1.000000 -0.033366  0.025457
# valence              0.053867         -0.203283 -0.033366  1.000000  0.045089
# tempo                0.215504          0.018853  0.025457  0.045089  1.000000
# duration_ms          0.366976          0.184709 -0.090188 -0.039794  0.130328
#
#                   duration_ms
# energy               0.081971
# danceability        -0.033763
# key                 -0.003345
# loudness             0.064130
# acousticness        -0.010988
# speechiness          0.366976
# instrumentalness     0.184709
# liveness            -0.090188
# valence             -0.039794
# tempo                0.130328
# duration_ms          1.000000

# %%
cor_matrix_stacked = cor_matrix.unstack()

# %%
cor_matrix_stacked = cor_matrix_stacked[cor_matrix_stacked != 1]

# %%
cor_matrix_stacked.sort_values()
# Out:
# energy            acousticness       -0.682479
# acousticness      energy             -0.682479
# loudness          instrumentalness   -0.553735
# instrumentalness  loudness           -0.553735
# acousticness      loudness           -0.498695
#                                         ...
# loudness          valence             0.406772
# danceability      valence             0.479953
# valence           danceability        0.479953
# energy            loudness            0.791640
# loudness          energy              0.791640
# Length: 110, dtype: float64

# %%
correlation_dict_mirrored = cor_matrix_stacked.sort_values().to_dict()
correlation_dict_mirrored
# Out:
# {('energy', 'acousticness'): -0.6824785203241528,
#  ('acousticness', 'energy'): -0.6824785203241528,
#  ('loudness', 'instrumentalness'): -0.5537348090851054,
#  ('instrumentalness', 'loudness'): -0.5537348090851054,
#  ('acousticness', 'loudness'): -0.4986950326515534,
#  ('loudness', 'acousticness'): -0.4986950326515534,
#  ('instrumentalness', 'energy'): -0.38551503859807107,
#  ('energy', 'instrumentalness'): -0.38551503859807107,
#  ('danceability', 'acousticness'): -0.35913454296071834,
#  ('acousticness', 'danceability'): -0.35913454296071834,
#  ('acousticness', 'valence'): -0.24319225768729424,
#  ('valence', 'acousticness'): -0.24319225768729424,
#  ('tempo', 'acousticness'): -0.24111873337229978,
#  ('acousticness', 'tempo'): -0.24111873337229978,
#  ('valence', 'instrumentalness'): -0.20328292297434575,
#  ('instrumentalness', 'valence'): -0.20328292297434575,
#  ('speechiness', 'liveness'): -0.14295683598584816,
#  ('liveness', 'speechiness'): -0.14295683598584816,
#  ('speechiness', 'acousticness'): -0.13539214333859012,
#  ('acousticness', 'speechiness'): -0.13539214333859012,
#  ('liveness', 'acousticness'): -0.12838374099020403,
#  ('acousticness', 'liveness'): -0.12838374099020403,
#  ('acousticness', 'key'): -0.11339351100259196,
#  ('key', 'acousticness'): -0.11339351100259196,
#  ('key', 'speechiness'): -0.09496505735843172,
#  ('speechiness', 'key'): -0.09496505735843172,
#  ('duration_ms', 'liveness'): -0.09018826695099239,
#  ('liveness', 'duration_ms'): -0.09018826695099239,
#  ('liveness', 'instrumentalness'): -0.0870339124461283,
#  ('instrumentalness', 'liveness'): -0.0870339124461283,
#  ('loudness', 'liveness'): -0.06993949725852708,
#  ('liveness', 'loudness'): -0.06993949725852708,
#  ('valence', 'duration_ms'): -0.03979436283824896,
#  ('duration_ms', 'valence'): -0.03979436283824896,
#  ('duration_ms', 'danceability'): -0.033763480296644874,
#  ('danceability', 'duration_ms'): -0.033763480296644874,
#  ('valence', 'liveness'): -0.03336630340518706,
#  ('liveness', 'valence'): -0.03336630340518706,
#  ('loudness', 'speechiness'): -0.021692935459647147,
#  ('speechiness', 'loudness'): -0.021692935459647147,
#  ('danceability', 'instrumentalness'): -0.01770638521729678,
#  ('instrumentalness', 'danceability'): -0.01770638521729678,
#  ('acousticness', 'duration_ms'): -0.010988051809892976,
#  ('duration_ms', 'acousticness'): -0.010988051809892976,
#  ('key', 'loudness'): -0.009178410631968104,
#  ('loudness', 'key'): -0.009178410631968104,
#  ('liveness', 'danceability'): -0.006648475599485623,
#  ('danceability', 'liveness'): -0.006648475599485623,
#  ('key', 'duration_ms'): -0.003345303142861897,
#  ('duration_ms', 'key'): -0.003345303142861897,
#  ('tempo', 'instrumentalness'): 0.01885267572734445,
#  ('instrumentalness', 'tempo'): 0.01885267572734445,
#  ('instrumentalness', 'key'): 0.020802356350748005,
#  ('key', 'instrumentalness'): 0.020802356350748005,
#  ('tempo', 'liveness'): 0.025456740041450245,
#  ('liveness', 'tempo'): 0.025456740041450245,
#  ('instrumentalness', 'speechiness'): 0.028948017426321342,
#  ('speechiness', 'instrumentalness'): 0.028948017426321342,
#  ('valence', 'tempo'): 0.04508867269936379,
#  ('tempo', 'valence'): 0.04508867269936379,
#  ('speechiness', 'valence'): 0.05386720274013534,
#  ('valence', 'speechiness'): 0.05386720274013534,
#  ('energy', 'key'): 0.062428155998836,
#  ('key', 'energy'): 0.062428155998836,
#  ('loudness', 'duration_ms'): 0.06413020411872389,
#  ('duration_ms', 'loudness'): 0.06413020411872389,
#  ('liveness', 'energy'): 0.0694873918471837,
#  ('energy', 'liveness'): 0.0694873918471837,
#  ('energy', 'speechiness'): 0.07426734162813511,
#  ('speechiness', 'energy'): 0.07426734162813511,
#  ('energy', 'tempo'): 0.07519058796876629,
#  ('tempo', 'energy'): 0.07519058796876629,
#  ('tempo', 'key'): 0.080474600534549,
#  ('key', 'tempo'): 0.080474600534549,
#  ('energy', 'duration_ms'): 0.08197097916072248,
#  ('duration_ms', 'energy'): 0.08197097916072248,
#  ('tempo', 'loudness'): 0.10209731694965224,
#  ('loudness', 'tempo'): 0.10209731694965224,
#  ('key', 'valence'): 0.12000703543354213,
#  ('valence', 'key'): 0.12000703543354213,
#  ('tempo', 'duration_ms'): 0.13032802699077664,
#  ('duration_ms', 'tempo'): 0.13032802699077664,
#  ('energy', 'danceability'): 0.15255172184057095,
#  ('danceability', 'energy'): 0.15255172184057095,
#  ('loudness', 'danceability'): 0.16714724611260234,
#  ('danceability', 'loudness'): 0.16714724611260234,
#  ('tempo', 'danceability'): 0.16895565119277534,
#  ('danceability', 'tempo'): 0.16895565119277534,
#  ('instrumentalness', 'duration_ms'): 0.18470865100256503,
#  ('duration_ms', 'instrumentalness'): 0.18470865100256503,
#  ('speechiness', 'tempo'): 0.21550364529588156,
#  ('tempo', 'speechiness'): 0.21550364529588156,
#  ('danceability', 'speechiness'): 0.22614782762508626,
#  ('speechiness', 'danceability'): 0.22614782762508626,
#  ('liveness', 'key'): 0.2786720187652891,
#  ('key', 'liveness'): 0.2786720187652891,
#  ('danceability', 'key'): 0.28503633104389425,
#  ('key', 'danceability'): 0.28503633104389425,
#  ('acousticness', 'instrumentalness'): 0.3521844097415598,
#  ('instrumentalness', 'acousticness'): 0.3521844097415598,
#  ('duration_ms', 'speechiness'): 0.3669756307580245,
#  ('speechiness', 'duration_ms'): 0.3669756307580245,
#  ('energy', 'valence'): 0.3934532373133881,
#  ('valence', 'energy'): 0.3934532373133881,
#  ('valence', 'loudness'): 0.4067721170119213,
#  ('loudness', 'valence'): 0.4067721170119213,
#  ('danceability', 'valence'): 0.4799533854156742,
#  ('valence', 'danceability'): 0.4799533854156742,
#  ('energy', 'loudness'): 0.7916395653045617,
#  ('loudness', 'energy'): 0.7916395653045617}

# %%
correlation_dict = {}

# %%
for item in correlation_dict_mirrored:
    if (item[1], item[0]) not in correlation_dict:
        correlation_dict.update({item: correlation_dict_mirrored[item]})

# %%
correlation_dict
# Out:
# {('energy', 'acousticness'): -0.6824785203241528,
#  ('loudness', 'instrumentalness'): -0.5537348090851054,
#  ('acousticness', 'loudness'): -0.4986950326515534,
#  ('instrumentalness', 'energy'): -0.38551503859807107,
#  ('danceability', 'acousticness'): -0.35913454296071834,
#  ('acousticness', 'valence'): -0.24319225768729424,
#  ('tempo', 'acousticness'): -0.24111873337229978,
#  ('valence', 'instrumentalness'): -0.20328292297434575,
#  ('speechiness', 'liveness'): -0.14295683598584816,
#  ('speechiness', 'acousticness'): -0.13539214333859012,
#  ('liveness', 'acousticness'): -0.12838374099020403,
#  ('acousticness', 'key'): -0.11339351100259196,
#  ('key', 'speechiness'): -0.09496505735843172,
#  ('duration_ms', 'liveness'): -0.09018826695099239,
#  ('liveness', 'instrumentalness'): -0.0870339124461283,
#  ('loudness', 'liveness'): -0.06993949725852708,
#  ('valence', 'duration_ms'): -0.03979436283824896,
#  ('duration_ms', 'danceability'): -0.033763480296644874,
#  ('valence', 'liveness'): -0.03336630340518706,
#  ('loudness', 'speechiness'): -0.021692935459647147,
#  ('danceability', 'instrumentalness'): -0.01770638521729678,
#  ('acousticness', 'duration_ms'): -0.010988051809892976,
#  ('key', 'loudness'): -0.009178410631968104,
#  ('liveness', 'danceability'): -0.006648475599485623,
#  ('key', 'duration_ms'): -0.003345303142861897,
#  ('tempo', 'instrumentalness'): 0.01885267572734445,
#  ('instrumentalness', 'key'): 0.020802356350748005,
#  ('tempo', 'liveness'): 0.025456740041450245,
#  ('instrumentalness', 'speechiness'): 0.028948017426321342,
#  ('valence', 'tempo'): 0.04508867269936379,
#  ('speechiness', 'valence'): 0.05386720274013534,
#  ('energy', 'key'): 0.062428155998836,
#  ('loudness', 'duration_ms'): 0.06413020411872389,
#  ('liveness', 'energy'): 0.0694873918471837,
#  ('energy', 'speechiness'): 0.07426734162813511,
#  ('energy', 'tempo'): 0.07519058796876629,
#  ('tempo', 'key'): 0.080474600534549,
#  ('energy', 'duration_ms'): 0.08197097916072248,
#  ('tempo', 'loudness'): 0.10209731694965224,
#  ('key', 'valence'): 0.12000703543354213,
#  ('tempo', 'duration_ms'): 0.13032802699077664,
#  ('energy', 'danceability'): 0.15255172184057095,
#  ('loudness', 'danceability'): 0.16714724611260234,
#  ('tempo', 'danceability'): 0.16895565119277534,
#  ('instrumentalness', 'duration_ms'): 0.18470865100256503,
#  ('speechiness', 'tempo'): 0.21550364529588156,
#  ('danceability', 'speechiness'): 0.22614782762508626,
#  ('liveness', 'key'): 0.2786720187652891,
#  ('danceability', 'key'): 0.28503633104389425,
#  ('acousticness', 'instrumentalness'): 0.3521844097415598,
#  ('duration_ms', 'speechiness'): 0.3669756307580245,
#  ('energy', 'valence'): 0.3934532373133881,
#  ('valence', 'loudness'): 0.4067721170119213,
#  ('danceability', 'valence'): 0.4799533854156742,
#  ('energy', 'loudness'): 0.7916395653045617}

# %% [markdown]
# ('energy', 'loudness') are strongly positively correlated: 0.7916395653045617}

# %% [markdown]
# ### Which features are strongly negatively correlated?

# %% [markdown]
# ('energy', 'acousticness'): -0.6824785203241528
# is close to count as strongly

# %% [markdown]
# ### Which features are not correlated?

# %%
[{item: correlation_dict[item]} for item in correlation_dict if abs(correlation_dict[item])<=0.1]
# Out:
# [{('key', 'speechiness'): -0.09496505735843172},
#  {('duration_ms', 'liveness'): -0.09018826695099239},
#  {('liveness', 'instrumentalness'): -0.0870339124461283},
#  {('loudness', 'liveness'): -0.06993949725852708},
#  {('valence', 'duration_ms'): -0.03979436283824896},
#  {('duration_ms', 'danceability'): -0.033763480296644874},
#  {('valence', 'liveness'): -0.03336630340518706},
#  {('loudness', 'speechiness'): -0.021692935459647147},
#  {('danceability', 'instrumentalness'): -0.01770638521729678},
#  {('acousticness', 'duration_ms'): -0.010988051809892976},
#  {('key', 'loudness'): -0.009178410631968104},
#  {('liveness', 'danceability'): -0.006648475599485623},
#  {('key', 'duration_ms'): -0.003345303142861897},
#  {('tempo', 'instrumentalness'): 0.01885267572734445},
#  {('instrumentalness', 'key'): 0.020802356350748005},
#  {('tempo', 'liveness'): 0.025456740041450245},
#  {('instrumentalness', 'speechiness'): 0.028948017426321342},
#  {('valence', 'tempo'): 0.04508867269936379},
#  {('speechiness', 'valence'): 0.05386720274013534},
#  {('energy', 'key'): 0.062428155998836},
#  {('loudness', 'duration_ms'): 0.06413020411872389},
#  {('liveness', 'energy'): 0.0694873918471837},
#  {('energy', 'speechiness'): 0.07426734162813511},
#  {('energy', 'tempo'): 0.07519058796876629},
#  {('tempo', 'key'): 0.080474600534549},
#  {('energy', 'duration_ms'): 0.08197097916072248}]

# %% [markdown]
# pairs with correlaction within -0.1 to 0.1 are considered as not correlated here.

# %% [markdown]
# ### How does the danceability score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?

# %%
danceability_genre = df.groupby('genre')['danceability'].agg(['min', 'mean', 'median', 'max'])
danceability_genre
# Out:
#                                       min      mean  median    max
# genre
#  Electro-pop                        0.701  0.789500  0.7895  0.878
# Alternative/Indie                   0.459  0.661750  0.6630  0.862
# Alternative/reggaeton/experimental  0.607  0.607000  0.6070  0.607
# Chamber pop                         0.351  0.351000  0.3510  0.351
# Dance-pop/Disco                     0.730  0.730000  0.7300  0.730
# Dance/Electronic                    0.647  0.755000  0.7850  0.880
# Disco-pop                           0.746  0.746000  0.7460  0.746
# Dreampop/Hip-Hop/R&B                0.755  0.755000  0.7550  0.755
# Hip-Hop/Rap                         0.598  0.765538  0.7740  0.896
# Hip-Hop/Trap                        0.935  0.935000  0.9350  0.935
# Nu-disco                            0.793  0.793000  0.7930  0.793
# Pop                                 0.464  0.677571  0.6900  0.806
# Pop rap                             0.700  0.700000  0.7000  0.700
# Pop/Soft Rock                       0.695  0.695000  0.6950  0.695
# R&B/Hip-Hop alternative             0.784  0.784000  0.7840  0.784
# R&B/Soul                            0.514  0.650500  0.6505  0.787

# %%
danceability_genres_interested = ['Pop', 'Hip-Hop/Rap', 'Dance/Electronic', 'Alternative/Indie']

# %%
danceability_genre.loc[danceability_genres_interested]
# Out:
#                      min      mean  median    max
# genre
# Pop                0.464  0.677571   0.690  0.806
# Hip-Hop/Rap        0.598  0.765538   0.774  0.896
# Dance/Electronic   0.647  0.755000   0.785  0.880
# Alternative/Indie  0.459  0.661750   0.663  0.862

# %% [markdown]
# danceability doen't differ much for 'Pop', 'Hip-Hop/Rap', 'Dance/Electronic', 'Alternative/Indie' genres.

# %% [markdown]
# ### How does the acousticness score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?

# %%
acousticness_genre = df.groupby('genre')['acousticness'].agg(['min', 'mean', 'median', 'max'])
acousticness_genre
# Out:
#                                         min      mean   median     max
# genre
#  Electro-pop                        0.18300  0.255500  0.25550  0.3280
# Alternative/Indie                   0.29100  0.583500  0.64600  0.7510
# Alternative/reggaeton/experimental  0.01030  0.010300  0.01030  0.0103
# Chamber pop                         0.93400  0.934000  0.93400  0.9340
# Dance-pop/Disco                     0.16700  0.167000  0.16700  0.1670
# Dance/Electronic                    0.01370  0.099440  0.06860  0.2230
# Disco-pop                           0.01120  0.011200  0.01120  0.0112
# Dreampop/Hip-Hop/R&B                0.53300  0.533000  0.53300  0.5330
# Hip-Hop/Rap                         0.00513  0.188741  0.14500  0.7310
# Hip-Hop/Trap                        0.01940  0.019400  0.01940  0.0194
# Nu-disco                            0.01230  0.012300  0.01230  0.0123
# Pop                                 0.02100  0.323843  0.25900  0.9020
# Pop rap                             0.22100  0.221000  0.22100  0.2210
# Pop/Soft Rock                       0.19200  0.192000  0.19200  0.1920
# R&B/Hip-Hop alternative             0.12300  0.123000  0.12300  0.1230
# R&B/Soul                            0.00146  0.128730  0.12873  0.2560

# %%
acousticness_genre.loc[danceability_genres_interested]
# Out:
#                        min      mean  median    max
# genre
# Pop                0.02100  0.323843  0.2590  0.902
# Hip-Hop/Rap        0.00513  0.188741  0.1450  0.731
# Dance/Electronic   0.01370  0.099440  0.0686  0.223
# Alternative/Indie  0.29100  0.583500  0.6460  0.751

# %% [markdown]
# Alternative/Indie genre has more acousticness score in average (0.583500) from specified genres. However maximum score has Pop genre song: 0.902.

# %% [markdown]
# Provide clear explanations in your notebook. Your explanations should inform the reader what you are trying to achieve, the results you got, and what these results mean.
# Provide suggestions for how your analysis could be improved.

# %% [markdown]
# ## Results

# %%
df.describe()
# Out:
#           energy  danceability        key   loudness  acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        speechiness  instrumentalness   liveness    valence       tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# 25%       0.048325          0.000000   0.093950   0.434000   99.557250
# 50%       0.070050          0.000000   0.111000   0.560000  116.969000
# 75%       0.155500          0.000020   0.271250   0.726250  132.317000
# max       0.487000          0.657000   0.792000   0.925000  180.067000
#
#          duration_ms
# count      50.000000
# mean   199955.360000
# std     33996.122488
# min    140526.000000
# 25%    175845.500000
# 50%    197853.500000
# 75%    215064.000000
# max    312820.000000

# %% [markdown]
# Average song in top50:

# %%
df.describe().loc['mean']
# Out:
# energy                   0.609300
# danceability             0.716720
# key                      5.720000
# loudness                -6.225900
# acousticness             0.256206
# speechiness              0.124158
# instrumentalness         0.015962
# liveness                 0.196552
# valence                  0.555710
# tempo                  119.690460
# duration_ms         199955.360000
# Name: mean, dtype: float64

# %% [markdown]
# the most popular genre according to the list is POP.

# %% [markdown]
# The dataset with 50 rows and 16 features. No missing data, no duplicates. There are values lying outside of 3 sigmas, but look to be adequate. So, dataset is clean.

# %% [markdown]
# Text type features: 'artist', 'album', 'track_name', 'track_id', 'genre'. Only one is categorical: genre.

# %% [markdown]
# 7 artists with more than one track in the list: ['Dua Lipa', 'Billie Eilish', 'Travis Scott', 'Harry Styles', 'Lewis Capaldi', 'Justin Bieber', 'Post Malone']

# %% [markdown]
# The most popular artists (with 3 songs in the list): 'Dua Lipa', 'Billie Eilish', 'Travis Scott'

# %% [markdown]
# 40 artists in total have their songs in the top 50

# %% [markdown]
# albums that have more than 1 popular track and tracks number: Future Nostalgia 3, Hollywood's Bleeding 2, Fine Line 2, Changes 2

# %% [markdown]
# albums in total have their songs in the top 50: 45

# %% [markdown]
# 32 tracks have a danceability score above 0.7

# %% [markdown]
# only 1 track has a danceability score below 0.4

# %% [markdown]
# 19 tracks have their loudness above -5

# %% [markdown]
# 9 tracks have their loudness below -8

# %% [markdown]
# 'SICKO MODE' is the longest in the list with 312 secs (5mins 12 secs)

# %% [markdown]
# 'Mood (feat. iann dior)' is the shortest song: 141 secs (2 mins 21 secs)

# %% [markdown]
# POP genre has the greatest number songs in the list: 14.

# %% [markdown]
# 2 genres are the leaders in the dataset: Pop with 14 songs, Hip-Hop/Rap with 13.
# The others: Dance/Electronic                       5
# Alternative/Indie                      4
# R&B/Soul                               2
#  Electro-pop                           2

# %% [markdown]
# 10 genres have just one song on the top 50: 'R&B/Hip-Hop alternative', 'Nu-disco', 'Pop/Soft Rock', 'Pop rap', 'Hip-Hop/Trap', 'Dance-pop/Disco', 'Disco-pop', 'Dreampop/Hip-Hop/R&B', 'Alternative/reggaeton/experimental', 'Chamber pop'

# %% [markdown]
# 16 genres in total are represented in the top 50

# %% [markdown]
# ('energy', 'loudness') are strongly positively correlated: 0.7916395653045617}

# %% [markdown]
# ('energy', 'acousticness'): -0.6824785203241528 is close to count as strongly

# %% [markdown]
# danceability don't differ much for 'Pop', 'Hip-Hop/Rap', 'Dance/Electronic', 'Alternative/Indie' genres.

# %% [markdown]
# Alternative/Indie genre has more acousticness score in average (0.583500) from leader genres. However maximum score has Pop genre song: 0.902
